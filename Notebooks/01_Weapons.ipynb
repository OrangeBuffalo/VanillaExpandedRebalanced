# %%
import string
import xmltodict
import untangle
import pandas as pd

# %% [markdown]
# ## Melee

# %%
def parse_xml(fp: str) -> pd.DataFrame:
    xml = untangle.parse(fp)
    data = []
    for thingdef in xml.Defs.ThingDef:
        try:
            name = thingdef.defName.cdata
        except AttributeError:
            continue
        data.append(
            {
                "name": name,
                "attacks": [parse_attack(li) for li in thingdef.tools.li]
            }
        )
    df = pd.DataFrame(data)
    df["dps"] = df.attacks.apply(lambda x: calculate_dps(x))
    df["ap"] = [max([attack["armorPenetration"] for attack in attacks]) * 100 for attacks in df.attacks]
    df.set_index("name", inplace=True)
    #df.drop(columns="attacks", inplace=True)
    return df

# %%
def parse_attack(li: untangle.Element):
    attack = {}
    attack["damage"] = float(li.power.cdata)
    attack["cooldown"] = float(li.cooldownTime.cdata)
    if li.get_elements("armorPenetration"):
        attack["armorPenetration"] = float(li.armorPenetration.cdata)
    else:
        attack["armorPenetration"] = attack["damage"] * 0.015
    return attack

# %%
def calculate_dps(attacks: list) -> float:
    weights = [attack["damage"] * attack["damage"] for attack in attacks]
    chances = [weight / sum(weights) for weight in weights]
    avg_dmg = sum([attacks[i]["damage"] * chances[i] for i in range(len(attacks))])
    avg_cooldown = sum([attacks[i]["cooldown"] * chances[i] for i in range(len(attacks))])
    return round(avg_dmg / avg_cooldown, 2)

# %%
medieval = parse_xml("C:/Games/Steam/steamapps/common/RimWorld/Data/Core/Defs/ThingDefs_Misc/Weapons/MeleeMedieval.xml")
neolithic = parse_xml("C:/Games/Steam/steamapps/common/RimWorld/Data/Core/Defs/ThingDefs_Misc/Weapons/MeleeNeolithic.xml")
medieval_ideology = parse_xml("C:/Games/Steam/steamapps/common/RimWorld/Data/Royalty/Defs/ThingDefs_Misc/Weapons/MeleeMedieval.xml")
ultratech = parse_xml("C:/Games/Steam/steamapps/common/RimWorld/Data/Royalty/Defs/ThingDefs_Misc/Weapons/MeleeUltratech.xml")
bladelink = parse_xml("C:/Games/Steam/steamapps/common/RimWorld/Data/Royalty/Defs/ThingDefs_Misc/Weapons/MeleeBladelink.xml")

# %%
melee = pd.concat((medieval, neolithic, medieval_ideology, ultratech, bladelink))

# %%
melee.sort_values(by="dps", ascending=False)
# Out:
#                                     dps     ap
# name
# MeleeWeapon_MonoSwordBladelink    16.03  90.00
# MeleeWeapon_ZeusHammerBladelink   13.40  46.50
# MeleeWeapon_MonoSword             12.08  90.00
# MeleeWeapon_PlasmaSwordBladelink  11.11  34.50
# MeleeWeapon_Zeushammer             9.95  46.50
# MeleeWeapon_LongSword              8.60  34.50
# MeleeWeapon_Spear                  7.91  50.00
# MeleeWeapon_PlasmaSword            7.85  31.50
# MeleeWeapon_Gladius                7.52  24.00
# MeleeWeapon_Ikwa                   7.04  22.50
# MeleeWeapon_Mace                   7.02  23.55
# MeleeWeapon_Warhammer              6.89  30.00
# MeleeWeapon_Axe                    6.71  22.50
# MeleeWeapon_Knife                  6.50  19.50
# MeleeWeapon_Club                   6.27  21.00

# %%
vwe_industrial = parse_xml("C:/Games/Steam/steamapps/workshop/content/294100/1814383360/1.3/Defs/ThingDefs_Misc/Weapons/MeleeIndustrial.xml")
vwe_medieval = parse_xml("C:/Games/Steam/steamapps/workshop/content/294100/1814383360/1.3/Defs/ThingDefs_Misc/Weapons/MeleeMedieval.xml")
vwe_neolithic = parse_xml("C:/Games/Steam/steamapps/workshop/content/294100/1814383360/1.3/Defs/ThingDefs_Misc/Weapons/MeleeNeolithic.xml")
vwe_tribal_neolithic = parse_xml("C:/Games/Steam/steamapps/workshop/content/294100/2454918552/1.3/Defs/ThingDefs_Misc/MeleeNeolithic.xml")
vwe_viking_medieval = parse_xml("C:/Games/Steam/steamapps/workshop/content/294100/2231295285/1.3/Defs/ThingDefs_Misc/Weapons/MeleeMedieval.xml")
vwe_viking_ultra = parse_xml("C:/Games/Steam/steamapps/workshop/content/294100/2231295285/1.3/Defs/ThingDefs_Misc/Weapons/MeleeUltra.xml")

# %%
melee = pd.concat((melee, vwe_industrial, vwe_medieval, vwe_neolithic, vwe_tribal_neolithic, vwe_viking_medieval, vwe_viking_ultra))

# %%
melee.sort_values(by="dps", ascending=False)
# Out:
#                                     dps     ap
# name
# MeleeWeapon_MonoSwordBladelink    16.03  90.00
# MeleeWeapon_ZeusHammerBladelink   13.40  46.50
# MeleeWeapon_MonoSword             12.08  90.00
# MeleeWeapon_PlasmaSwordBladelink  11.11  34.50
# VFEV_CryptoHeavyAxe               10.89  35.00
# MeleeWeapon_Zeushammer             9.95  46.50
# VWE_MeleeWeapon_Halberd            9.23  70.00
# MeleeWeapon_LongSword              8.60  34.50
# VWE_MeleeWeapon_BattleAxe          8.43  15.00
# VWE_MeleeWeapon_HeavyClub          8.35  34.50
# VWE_MeleeWeapon_CombatKnife        8.29  21.00
# VWE_MeleeWeapon_Shiv               8.00  18.00
# MeleeWeapon_Spear                  7.91  50.00
# MeleeWeapon_PlasmaSword            7.85  31.50
# MeleeWeapon_Gladius                7.52  24.00
# VWE_MeleeWeapon_Shovel             7.47  22.50
# VFE_MeleeWeapon_DaneAxe            7.37  34.50
# VWE_MeleeWeapon_Baton              7.18  18.00
# VWE_MeleeWeapon_Cleaver            7.16  24.00
# MeleeWeapon_Ikwa                   7.04  22.50
# MeleeWeapon_Mace                   7.02  23.55
# MeleeWeapon_Warhammer              6.89  30.00
# MeleeWeapon_Axe                    6.71  22.50
# VWE_MeleeWeapon_Axe                6.64  25.00
# VWE_MeleeWeapon_Pickaxe            6.50  35.00
# MeleeWeapon_Knife                  6.50  19.50
# VWE_MeleeWeapon_Hammer             6.27  21.00
# MeleeWeapon_Club                   6.27  21.00
# VWE_MeleeWeapon_Wrench             6.26  45.00
# VFE_MeleeWeapon_Seax               6.04  13.50
# VFEV_CryptoLightAxe                5.96  35.00
# VWE_MeleeWeapon_TribalAxe          5.46  18.00
# VFE_MeleeWeapon_BeardedAxe         4.87  19.50
# VWE_MeleeWeapon_Scalpel            4.24  12.00
# VWE_MeleeWeapon_LightClub          4.04  13.50

# %% [markdown]
# * Halberds have too much Armor Penetration
# * Combat knifes and Shivs have too high DPS
# * Shovels have more DPS than Dane Axe
# * Wrench and Seax should be last
# * Combat Knife and Shiv have higher AP than Battle Axe and more DPS than Gladius / DaneAxe ?

# %% [markdown]
# ## Armor

# %%
def parse_xml(fp: str) -> pd.DataFrame:
    with open(fp, "rb") as f:
        defs = xmltodict.parse(f)["Defs"]
    data = []
    for thingdef in defs["ThingDef"]:
        name = thingdef.get("defName")
        stats = thingdef.get("statBases")
        offsets = thingdef.get("equippedStatOffsets")
        if name and stats:
            data.append({
                "name": name,
                "stuff_effect_multiplier_armor": stats.get("StuffEffectMultiplierArmor"),
                "armor_rating_sharp": stats.get("ArmorRating_Sharp"),
                "armor_rating_blunt": stats.get("ArmorRating_Blunt"),
                "armor_rating_heat": stats.get("ArmorRating_Heat"),
                "insulation_cold": stats.get("Insulation_Cold"),
                "insulation_heat": stats.get("Insulation_Heat"),
                "stuff_effect_multiplier_insulation_cold": stats.get("StuffEffectMultiplierInsulation_Cold"),
                "stuff_effect_multiplier_insulation_heat": stats.get("StuffEffectMultiplierInsulation_Heat"),
            })
            if offsets:
                data[-1].update(offsets=offsets)
            df = pd.DataFrame(data)
            for col in ("stuff_effect_multiplier_armor", "armor_rating_sharp", "armor_rating_blunt", "armor_rating_heat"):
                df[col] = df[col].apply(lambda x: float(x) if x else pd.NA)
        
    return df

# %%
core = parse_xml("C:/Games/Steam/steamapps/common/RimWorld/Data/Core/Defs/ThingDefs_Misc/Apparel_Various.xml")
ideology = parse_xml("C:/Games/Steam/steamapps/common/RimWorld/Data/Ideology/Defs/ThingDefs_Misc/Apparel_Various.xml")
royalty = parse_xml("C:/Games/Steam/steamapps/common/RimWorld/Data/Royalty/Defs/ThingDefs_Misc/Apparel_Various.xml")
vae_industrial = parse_xml("C:/Games/Steam/steamapps/workshop/content/294100/1814988282/1.3/Defs/ThingDefs_Misc/Armor_Industrial.xml")
vae_medieval = parse_xml("C:/Games/Steam/steamapps/workshop/content/294100/1814988282/1.3/Defs/ThingDefs_Misc/Armor_Medieval.xml")
vae_neolithic = parse_xml("C:/Games/Steam/steamapps/workshop/content/294100/1814988282/1.3/Defs/ThingDefs_Misc/Armor_Neolithic.xml")
vae_spacer = parse_xml("C:/Games/Steam/steamapps/workshop/content/294100/1814988282/1.3/Defs/ThingDefs_Misc/Armor_Spacer.xml")
vae_apparel_industrial = parse_xml("C:/Games/Steam/steamapps/workshop/content/294100/1814987817/1.3/Defs/ThingDefs_Misc/Apparel_Industrial.xml")
vae_apparel_medieval = parse_xml("C:/Games/Steam/steamapps/workshop/content/294100/1814987817/1.3/Defs/ThingDefs_Misc/Apparel_Medieval.xml")
vae_apparel_neolithic = parse_xml("C:/Games/Steam/steamapps/workshop/content/294100/1814987817/1.3/Defs/ThingDefs_Misc/Apparel_Neolithic.xml")
vfe_viking = parse_xml("C:/Games/Steam/steamapps/workshop/content/294100/2231295285/1.3/Defs/ThingDefs_Misc/Apparel_Various.xml")

# %%
armors = pd.concat((core, ideology, royalty, vae_industrial, vae_medieval, vae_neolithic, vae_spacer, vfe_viking, vae_apparel_industrial, vae_apparel_medieval, vae_apparel_neolithic))
armors["move_speed"] = armors.offsets.apply(lambda x: float(x.get("MoveSpeed", 0)) if not pd.isna(x) else None)

# %%
pd.options.display.max_rows = 999

# %%
armors.set_index("name").sort_values(by="stuff_effect_multiplier_armor", ascending=False)
# Out:
#                                       stuff_effect_multiplier_armor  \
# name
# VAE_Apparel_AdvancedVest                                        1.0
# VAE_Apparel_PlateShoulderpads                                  0.88
# VFEV_Apparel_GuardianArmor                                     0.85
# VAE_Apparel_LightPlateArmor                                    0.73
# Apparel_PlateArmor                                             0.73
# VAE_Apparel_Chestplate                                         0.73
# VFEV_Apparel_RavagerArmor                                      0.58
# VFEV_LeatherArmor                                              0.55
# VAE_Apparel_Chainmail                                          0.46
# VAE_Apparel_PlateHelmet                                         0.4
# VAE_Apparel_MilitaryUniform                                    0.36
# VAE_Apparel_QuiltedVest                                        0.36
# VAE_Apparel_Jumpsuit                                           0.32
# VAE_Apparel_Jeans                                              0.32
# VAE_Apparel_MilitaryJacket                                      0.3
# Apparel_Jacket                                                  0.3
# Apparel_Duster                                                  0.3
# VAE_Apparel_PeltCoat                                            0.3
# VAE_Apparel_Gambeson                                            0.3
# VFEV_Apparel_JarlCape                                           0.3
# VFEV_Apparel_RoyalFurCoat                                       0.3
# VAE_Apparel_ChefsUniform                                       0.28
# VAE_Apparel_Apron                                              0.25
# VAE_Apparel_SuitJacket                                         0.23
# VAE_Apparel_Tunic                                               0.2
# VAE_Apparel_TankTop                                             0.2
# VAE_Apparel_TribalKilt                                          0.2
# VAE_Apparel_TribalPoncho                                        0.2
# VAE_Apparel_SheriffShirt                                        0.2
# VAE_Headgear_SummerHat                                          0.2
# VAE_Headgear_TrapperHat                                         0.2
# VAE_Apparel_Cape                                                0.2
# VAE_Apparel_Overalls                                            0.2
# Apparel_TribalA                                                 0.2
# VAE_Apparel_CasualTShirt                                        0.2
# VAE_Headgear_Fedora                                             0.2
# Apparel_Parka                                                   0.2
# Apparel_Pants                                                   0.2
# Apparel_BasicShirt                                              0.2
# Apparel_CollarShirt                                             0.2
# Apparel_Burka                                                   0.2
# Apparel_Robe                                                    0.2
# VAE_Headgear_Hood                                               0.2
# VAE_Apparel_Hoodie                                              0.2
# VAE_Apparel_ShirtandTie                                         0.2
# VAE_Apparel_Trousers                                            0.2
# VAE_Apparel_FleeceShirt                                        0.16
# Apparel_TortureCrown                                           0.15
# VAE_Apparel_Skirt                                              0.12
# VAE_Apparel_Blouse                                              0.1
# VAE_Apparel_Shorts                                              0.1
# Apparel_BodyStrap                                               0.1
# Apparel_Blindfold                                               0.1
# VAE_Apparel_HAZMATSuit                                         0.04
# Apparel_FlakVest                                               <NA>
# Apparel_FlakPants                                              <NA>
# Apparel_FlakJacket                                             <NA>
# Apparel_ArmorReconPrestige                                     <NA>
# Apparel_ArmorHelmetReconPrestige                               <NA>
# Apparel_ArmorMarinePrestige                                    <NA>
# Apparel_ArmorMarineHelmetPrestige                              <NA>
# Apparel_ArmorCataphractPrestige                                <NA>
# Apparel_ArmorHelmetCataphractPrestige                          <NA>
# Apparel_ArmorLocust                                            <NA>
# Apparel_ArmorMarineGrenadier                                   <NA>
# Apparel_ArmorCataphractPhoenix                                 <NA>
# Apparel_Gunlink                                                <NA>
# VAE_Apparel_BulletproofVest                                    <NA>
# VAE_Apparel_GhillieSuit                                        <NA>
# VAE_Apparel_WoodenArmor                                        <NA>
# VAE_Headgear_StoneWarMask                                      <NA>
# VAE_Headgear_TrooperHelmet                                     <NA>
# VAE_Apparel_TrooperArmor                                       <NA>
# VAE_Headgear_HeavyMarineHelmet                                 <NA>
# VAE_Apparel_HeavyMarineArmor                                   <NA>
# VFEV_CryptoArmor                                               <NA>
# VFEV_Apparel_CryptoHeavyHelmet                                 <NA>
# VAE_Apparel_BuildersJacket                                     <NA>
# VAE_Apparel_DoctorScrubs                                       <NA>
# VAE_Apparel_LabCoat                                            <NA>
#
#                                       armor_rating_sharp armor_rating_blunt  \
# name
# VAE_Apparel_AdvancedVest                            <NA>               <NA>
# VAE_Apparel_PlateShoulderpads                       <NA>               <NA>
# VFEV_Apparel_GuardianArmor                          <NA>               <NA>
# VAE_Apparel_LightPlateArmor                         <NA>               <NA>
# Apparel_PlateArmor                                  <NA>               <NA>
# VAE_Apparel_Chestplate                              <NA>               <NA>
# VFEV_Apparel_RavagerArmor                           <NA>               <NA>
# VFEV_LeatherArmor                                   <NA>               <NA>
# VAE_Apparel_Chainmail                               <NA>               <NA>
# VAE_Apparel_PlateHelmet                             <NA>               <NA>
# VAE_Apparel_MilitaryUniform                         <NA>               <NA>
# VAE_Apparel_QuiltedVest                             <NA>               <NA>
# VAE_Apparel_Jumpsuit                                <NA>               <NA>
# VAE_Apparel_Jeans                                   <NA>               <NA>
# VAE_Apparel_MilitaryJacket                          <NA>               <NA>
# Apparel_Jacket                                      <NA>               <NA>
# Apparel_Duster                                      <NA>               <NA>
# VAE_Apparel_PeltCoat                                <NA>               <NA>
# VAE_Apparel_Gambeson                                <NA>               <NA>
# VFEV_Apparel_JarlCape                               <NA>               <NA>
# VFEV_Apparel_RoyalFurCoat                           <NA>               <NA>
# VAE_Apparel_ChefsUniform                            <NA>               <NA>
# VAE_Apparel_Apron                                   <NA>               <NA>
# VAE_Apparel_SuitJacket                              <NA>               <NA>
# VAE_Apparel_Tunic                                   <NA>               <NA>
# VAE_Apparel_TankTop                                 <NA>               <NA>
# VAE_Apparel_TribalKilt                              <NA>               <NA>
# VAE_Apparel_TribalPoncho                            <NA>               <NA>
# VAE_Apparel_SheriffShirt                            <NA>               <NA>
# VAE_Headgear_SummerHat                              <NA>               <NA>
# VAE_Headgear_TrapperHat                             <NA>               <NA>
# VAE_Apparel_Cape                                    <NA>               <NA>
# VAE_Apparel_Overalls                                <NA>               <NA>
# Apparel_TribalA                                     <NA>               <NA>
# VAE_Apparel_CasualTShirt                            <NA>               <NA>
# VAE_Headgear_Fedora                                 <NA>               <NA>
# Apparel_Parka                                       <NA>               <NA>
# Apparel_Pants                                       <NA>               <NA>
# Apparel_BasicShirt                                  <NA>               <NA>
# Apparel_CollarShirt                                 <NA>               <NA>
# Apparel_Burka                                       <NA>               <NA>
# Apparel_Robe                                        <NA>               <NA>
# VAE_Headgear_Hood                                   <NA>               <NA>
# VAE_Apparel_Hoodie                                  <NA>               <NA>
# VAE_Apparel_ShirtandTie                             <NA>               <NA>
# VAE_Apparel_Trousers                                <NA>               <NA>
# VAE_Apparel_FleeceShirt                             <NA>               <NA>
# Apparel_TortureCrown                                <NA>               <NA>
# VAE_Apparel_Skirt                                   <NA>               <NA>
# VAE_Apparel_Blouse                                  <NA>               <NA>
# VAE_Apparel_Shorts                                  <NA>               <NA>
# Apparel_BodyStrap                                   <NA>               <NA>
# Apparel_Blindfold                                   <NA>               <NA>
# VAE_Apparel_HAZMATSuit                              <NA>               <NA>
# Apparel_FlakVest                                     1.0               0.36
# Apparel_FlakPants                                    0.4               0.08
# Apparel_FlakJacket                                   0.4               0.08
# Apparel_ArmorReconPrestige                          <NA>               <NA>
# Apparel_ArmorHelmetReconPrestige                    <NA>               <NA>
# Apparel_ArmorMarinePrestige                         <NA>               <NA>
# Apparel_ArmorMarineHelmetPrestige                   <NA>               <NA>
# Apparel_ArmorCataphractPrestige                     <NA>               <NA>
# Apparel_ArmorHelmetCataphractPrestige               <NA>               <NA>
# Apparel_ArmorLocust                                 0.87               0.35
# Apparel_ArmorMarineGrenadier                        1.01                0.4
# Apparel_ArmorCataphractPhoenix                      1.15               0.45
# Apparel_Gunlink                                      0.0                0.0
# VAE_Apparel_BulletproofVest                         1.08               0.22
# VAE_Apparel_GhillieSuit                             0.12               0.06
# VAE_Apparel_WoodenArmor                             0.55               0.24
# VAE_Headgear_StoneWarMask                           0.25               0.24
# VAE_Headgear_TrooperHelmet                          0.76               0.34
# VAE_Apparel_TrooperArmor                            0.65               0.35
# VAE_Headgear_HeavyMarineHelmet                       1.1               0.45
# VAE_Apparel_HeavyMarineArmor                        1.18               0.47
# VFEV_CryptoArmor                                    0.98               0.56
# VFEV_Apparel_CryptoHeavyHelmet                      1.06               0.65
# VAE_Apparel_BuildersJacket                          0.36                0.8
# VAE_Apparel_DoctorScrubs                             0.0                0.0
# VAE_Apparel_LabCoat                                 0.12                0.1
#
#                                       armor_rating_heat insulation_cold  \
# name
# VAE_Apparel_AdvancedVest                           <NA>            None
# VAE_Apparel_PlateShoulderpads                      <NA>            None
# VFEV_Apparel_GuardianArmor                         <NA>              40
# VAE_Apparel_LightPlateArmor                        <NA>            None
# Apparel_PlateArmor                                 <NA>            None
# VAE_Apparel_Chestplate                             <NA>            None
# VFEV_Apparel_RavagerArmor                          <NA>            None
# VFEV_LeatherArmor                                  <NA>            None
# VAE_Apparel_Chainmail                              <NA>            None
# VAE_Apparel_PlateHelmet                            <NA>            None
# VAE_Apparel_MilitaryUniform                        <NA>            None
# VAE_Apparel_QuiltedVest                            <NA>            None
# VAE_Apparel_Jumpsuit                               <NA>            None
# VAE_Apparel_Jeans                                  <NA>            None
# VAE_Apparel_MilitaryJacket                         <NA>            None
# Apparel_Jacket                                     <NA>            None
# Apparel_Duster                                     <NA>            None
# VAE_Apparel_PeltCoat                               <NA>            None
# VAE_Apparel_Gambeson                               <NA>            None
# VFEV_Apparel_JarlCape                              <NA>            None
# VFEV_Apparel_RoyalFurCoat                          <NA>            None
# VAE_Apparel_ChefsUniform                           <NA>            None
# VAE_Apparel_Apron                                  <NA>            None
# VAE_Apparel_SuitJacket                             <NA>            None
# VAE_Apparel_Tunic                                  <NA>            None
# VAE_Apparel_TankTop                                <NA>            None
# VAE_Apparel_TribalKilt                             <NA>            None
# VAE_Apparel_TribalPoncho                           <NA>            None
# VAE_Apparel_SheriffShirt                           <NA>            None
# VAE_Headgear_SummerHat                             <NA>            None
# VAE_Headgear_TrapperHat                            <NA>            None
# VAE_Apparel_Cape                                   <NA>            None
# VAE_Apparel_Overalls                               <NA>            None
# Apparel_TribalA                                    <NA>            None
# VAE_Apparel_CasualTShirt                           <NA>            None
# VAE_Headgear_Fedora                                <NA>            None
# Apparel_Parka                                      <NA>            None
# Apparel_Pants                                      <NA>            None
# Apparel_BasicShirt                                 <NA>            None
# Apparel_CollarShirt                                <NA>            None
# Apparel_Burka                                      <NA>            None
# Apparel_Robe                                       <NA>            None
# VAE_Headgear_Hood                                  <NA>            None
# VAE_Apparel_Hoodie                                 <NA>            None
# VAE_Apparel_ShirtandTie                            <NA>            None
# VAE_Apparel_Trousers                               <NA>            None
# VAE_Apparel_FleeceShirt                            <NA>            None
# Apparel_TortureCrown                               <NA>            None
# VAE_Apparel_Skirt                                  <NA>            None
# VAE_Apparel_Blouse                                 <NA>            None
# VAE_Apparel_Shorts                                 <NA>            None
# Apparel_BodyStrap                                  <NA>            None
# Apparel_Blindfold                                  <NA>            None
# VAE_Apparel_HAZMATSuit                             <NA>            None
# Apparel_FlakVest                                   0.27               1
# Apparel_FlakPants                                   0.1             3.5
# Apparel_FlakJacket                                  0.1            14.4
# Apparel_ArmorReconPrestige                         <NA>            None
# Apparel_ArmorHelmetReconPrestige                   <NA>            None
# Apparel_ArmorMarinePrestige                        <NA>            None
# Apparel_ArmorMarineHelmetPrestige                  <NA>            None
# Apparel_ArmorCataphractPrestige                    <NA>            None
# Apparel_ArmorHelmetCataphractPrestige              <NA>            None
# Apparel_ArmorLocust                                0.41            None
# Apparel_ArmorMarineGrenadier                       0.49            None
# Apparel_ArmorCataphractPhoenix                     0.75            None
# Apparel_Gunlink                                     0.0               0
# VAE_Apparel_BulletproofVest                        0.17               1
# VAE_Apparel_GhillieSuit                             0.0               6
# VAE_Apparel_WoodenArmor                             0.0               1
# VAE_Headgear_StoneWarMask                           0.1            None
# VAE_Headgear_TrooperHelmet                         0.56               2
# VAE_Apparel_TrooperArmor                           0.38              20
# VAE_Headgear_HeavyMarineHelmet                     0.56               4
# VAE_Apparel_HeavyMarineArmor                       0.48              35
# VFEV_CryptoArmor                                    0.6              30
# VFEV_Apparel_CryptoHeavyHelmet                     0.74              16
# VAE_Apparel_BuildersJacket                         0.27               6
# VAE_Apparel_DoctorScrubs                            0.0               6
# VAE_Apparel_LabCoat                                 0.1              12
#
#                                       insulation_heat  \
# name
# VAE_Apparel_AdvancedVest                         None
# VAE_Apparel_PlateShoulderpads                    None
# VFEV_Apparel_GuardianArmor                          9
# VAE_Apparel_LightPlateArmor                      None
# Apparel_PlateArmor                               None
# VAE_Apparel_Chestplate                           None
# VFEV_Apparel_RavagerArmor                        None
# VFEV_LeatherArmor                                None
# VAE_Apparel_Chainmail                            None
# VAE_Apparel_PlateHelmet                          None
# VAE_Apparel_MilitaryUniform                      None
# VAE_Apparel_QuiltedVest                          None
# VAE_Apparel_Jumpsuit                             None
# VAE_Apparel_Jeans                                None
# VAE_Apparel_MilitaryJacket                       None
# Apparel_Jacket                                   None
# Apparel_Duster                                   None
# VAE_Apparel_PeltCoat                             None
# VAE_Apparel_Gambeson                             None
# VFEV_Apparel_JarlCape                            None
# VFEV_Apparel_RoyalFurCoat                        None
# VAE_Apparel_ChefsUniform                         None
# VAE_Apparel_Apron                                None
# VAE_Apparel_SuitJacket                           None
# VAE_Apparel_Tunic                                None
# VAE_Apparel_TankTop                              None
# VAE_Apparel_TribalKilt                           None
# VAE_Apparel_TribalPoncho                         None
# VAE_Apparel_SheriffShirt                         None
# VAE_Headgear_SummerHat                           None
# VAE_Headgear_TrapperHat                          None
# VAE_Apparel_Cape                                 None
# VAE_Apparel_Overalls                             None
# Apparel_TribalA                                  None
# VAE_Apparel_CasualTShirt                         None
# VAE_Headgear_Fedora                              None
# Apparel_Parka                                    None
# Apparel_Pants                                    None
# Apparel_BasicShirt                               None
# Apparel_CollarShirt                              None
# Apparel_Burka                                    None
# Apparel_Robe                                     None
# VAE_Headgear_Hood                                None
# VAE_Apparel_Hoodie                               None
# VAE_Apparel_ShirtandTie                          None
# VAE_Apparel_Trousers                             None
# VAE_Apparel_FleeceShirt                          None
# Apparel_TortureCrown                             None
# VAE_Apparel_Skirt                                None
# VAE_Apparel_Blouse                               None
# VAE_Apparel_Shorts                               None
# Apparel_BodyStrap                                None
# Apparel_Blindfold                                None
# VAE_Apparel_HAZMATSuit                           None
# Apparel_FlakVest                                 None
# Apparel_FlakPants                                   1
# Apparel_FlakJacket                                  3
# Apparel_ArmorReconPrestige                       None
# Apparel_ArmorHelmetReconPrestige                 None
# Apparel_ArmorMarinePrestige                      None
# Apparel_ArmorMarineHelmetPrestige                None
# Apparel_ArmorCataphractPrestige                  None
# Apparel_ArmorHelmetCataphractPrestige            None
# Apparel_ArmorLocust                              None
# Apparel_ArmorMarineGrenadier                     None
# Apparel_ArmorCataphractPhoenix                    100
# Apparel_Gunlink                                     0
# VAE_Apparel_BulletproofVest                         0
# VAE_Apparel_GhillieSuit                             0
# VAE_Apparel_WoodenArmor                             0
# VAE_Headgear_StoneWarMask                        None
# VAE_Headgear_TrooperHelmet                          4
# VAE_Apparel_TrooperArmor                           10
# VAE_Headgear_HeavyMarineHelmet                      2
# VAE_Apparel_HeavyMarineArmor                       11
# VFEV_CryptoArmor                                   10
# VFEV_Apparel_CryptoHeavyHelmet                      3
# VAE_Apparel_BuildersJacket                          1
# VAE_Apparel_DoctorScrubs                            2
# VAE_Apparel_LabCoat                                 6
#
#                                       stuff_effect_multiplier_insulation_cold  \
# name
# VAE_Apparel_AdvancedVest                                                    1
# VAE_Apparel_PlateShoulderpads                                             0.1
# VFEV_Apparel_GuardianArmor                                               None
# VAE_Apparel_LightPlateArmor                                              0.14
# Apparel_PlateArmor                                                        1.0
# VAE_Apparel_Chestplate                                                   0.12
# VFEV_Apparel_RavagerArmor                                                1.06
# VFEV_LeatherArmor                                                        0.90
# VAE_Apparel_Chainmail                                                    0.05
# VAE_Apparel_PlateHelmet                                                  0.15
# VAE_Apparel_MilitaryUniform                                              0.22
# VAE_Apparel_QuiltedVest                                                  0.12
# VAE_Apparel_Jumpsuit                                                      0.3
# VAE_Apparel_Jeans                                                        0.32
# VAE_Apparel_MilitaryJacket                                                0.2
# Apparel_Jacket                                                           0.80
# Apparel_Duster                                                           0.60
# VAE_Apparel_PeltCoat                                                      1.8
# VAE_Apparel_Gambeson                                                     0.21
# VFEV_Apparel_JarlCape                                                     1.9
# VFEV_Apparel_RoyalFurCoat                                                 1.7
# VAE_Apparel_ChefsUniform                                                  0.2
# VAE_Apparel_Apron                                                        0.18
# VAE_Apparel_SuitJacket                                                   0.26
# VAE_Apparel_Tunic                                                        0.32
# VAE_Apparel_TankTop                                                       0.1
# VAE_Apparel_TribalKilt                                                   0.55
# VAE_Apparel_TribalPoncho                                                 0.55
# VAE_Apparel_SheriffShirt                                                 0.26
# VAE_Headgear_SummerHat                                                   0.10
# VAE_Headgear_TrapperHat                                                  0.70
# VAE_Apparel_Cape                                                         0.28
# VAE_Apparel_Overalls                                                      0.2
# Apparel_TribalA                                                          0.55
# VAE_Apparel_CasualTShirt                                                 0.22
# VAE_Headgear_Fedora                                                       0.1
# Apparel_Parka                                                            2.00
# Apparel_Pants                                                            0.20
# Apparel_BasicShirt                                                       0.22
# Apparel_CollarShirt                                                      0.26
# Apparel_Burka                                                             0.1
# Apparel_Robe                                                             0.80
# VAE_Headgear_Hood                                                         0.1
# VAE_Apparel_Hoodie                                                       0.32
# VAE_Apparel_ShirtandTie                                                  0.26
# VAE_Apparel_Trousers                                                      0.2
# VAE_Apparel_FleeceShirt                                                   0.1
# Apparel_TortureCrown                                                     None
# VAE_Apparel_Skirt                                                        0.14
# VAE_Apparel_Blouse                                                        0.1
# VAE_Apparel_Shorts                                                        0.1
# Apparel_BodyStrap                                                        0.10
# Apparel_Blindfold                                                        0.35
# VAE_Apparel_HAZMATSuit                                                      2
# Apparel_FlakVest                                                         None
# Apparel_FlakPants                                                        None
# Apparel_FlakJacket                                                       None
# Apparel_ArmorReconPrestige                                               None
# Apparel_ArmorHelmetReconPrestige                                         None
# Apparel_ArmorMarinePrestige                                              None
# Apparel_ArmorMarineHelmetPrestige                                        None
# Apparel_ArmorCataphractPrestige                                          None
# Apparel_ArmorHelmetCataphractPrestige                                    None
# Apparel_ArmorLocust                                                      None
# Apparel_ArmorMarineGrenadier                                             None
# Apparel_ArmorCataphractPhoenix                                           None
# Apparel_Gunlink                                                          None
# VAE_Apparel_BulletproofVest                                              None
# VAE_Apparel_GhillieSuit                                                  None
# VAE_Apparel_WoodenArmor                                                  None
# VAE_Headgear_StoneWarMask                                                0.05
# VAE_Headgear_TrooperHelmet                                               None
# VAE_Apparel_TrooperArmor                                                 None
# VAE_Headgear_HeavyMarineHelmet                                           None
# VAE_Apparel_HeavyMarineArmor                                             None
# VFEV_CryptoArmor                                                         None
# VFEV_Apparel_CryptoHeavyHelmet                                           None
# VAE_Apparel_BuildersJacket                                               None
# VAE_Apparel_DoctorScrubs                                                 None
# VAE_Apparel_LabCoat                                                      None
#
#                                       stuff_effect_multiplier_insulation_heat  \
# name
# VAE_Apparel_AdvancedVest                                                  0.6
# VAE_Apparel_PlateShoulderpads                                               0
# VFEV_Apparel_GuardianArmor                                               None
# VAE_Apparel_LightPlateArmor                                               0.0
# Apparel_PlateArmor                                                          0
# VAE_Apparel_Chestplate                                                   0.12
# VFEV_Apparel_RavagerArmor                                                0.11
# VFEV_LeatherArmor                                                        0.11
# VAE_Apparel_Chainmail                                                    0.05
# VAE_Apparel_PlateHelmet                                                     0
# VAE_Apparel_MilitaryUniform                                               0.2
# VAE_Apparel_QuiltedVest                                                  0.21
# VAE_Apparel_Jumpsuit                                                      0.2
# VAE_Apparel_Jeans                                                         0.1
# VAE_Apparel_MilitaryJacket                                                0.1
# Apparel_Jacket                                                           0.30
# Apparel_Duster                                                           0.85
# VAE_Apparel_PeltCoat                                                      0.1
# VAE_Apparel_Gambeson                                                      0.1
# VFEV_Apparel_JarlCape                                                     0.1
# VFEV_Apparel_RoyalFurCoat                                                 0.1
# VAE_Apparel_ChefsUniform                                                  0.2
# VAE_Apparel_Apron                                                        0.05
# VAE_Apparel_SuitJacket                                                    0.1
# VAE_Apparel_Tunic                                                        0.05
# VAE_Apparel_TankTop                                                      0.22
# VAE_Apparel_TribalKilt                                                   0.55
# VAE_Apparel_TribalPoncho                                                 0.55
# VAE_Apparel_SheriffShirt                                                  0.1
# VAE_Headgear_SummerHat                                                   0.50
# VAE_Headgear_TrapperHat                                                     0
# VAE_Apparel_Cape                                                            0
# VAE_Apparel_Overalls                                                     0.08
# Apparel_TribalA                                                          0.55
# VAE_Apparel_CasualTShirt                                                  0.1
# VAE_Headgear_Fedora                                                       0.1
# Apparel_Parka                                                            0.00
# Apparel_Pants                                                            0.08
# Apparel_BasicShirt                                                       0.10
# Apparel_CollarShirt                                                      0.10
# Apparel_Burka                                                             0.2
# Apparel_Robe                                                             0.25
# VAE_Headgear_Hood                                                        0.05
# VAE_Apparel_Hoodie                                                       0.10
# VAE_Apparel_ShirtandTie                                                   0.1
# VAE_Apparel_Trousers                                                     0.08
# VAE_Apparel_FleeceShirt                                                   0.4
# Apparel_TortureCrown                                                     None
# VAE_Apparel_Skirt                                                        0.22
# VAE_Apparel_Blouse                                                       0.32
# VAE_Apparel_Shorts                                                       0.25
# Apparel_BodyStrap                                                        0.10
# Apparel_Blindfold                                                           0
# VAE_Apparel_HAZMATSuit                                                      2
# Apparel_FlakVest                                                         None
# Apparel_FlakPants                                                        None
# Apparel_FlakJacket                                                       None
# Apparel_ArmorReconPrestige                                               None
# Apparel_ArmorHelmetReconPrestige                                         None
# Apparel_ArmorMarinePrestige                                              None
# Apparel_ArmorMarineHelmetPrestige                                        None
# Apparel_ArmorCataphractPrestige                                          None
# Apparel_ArmorHelmetCataphractPrestige                                    None
# Apparel_ArmorLocust                                                      None
# Apparel_ArmorMarineGrenadier                                             None
# Apparel_ArmorCataphractPhoenix                                           None
# Apparel_Gunlink                                                          None
# VAE_Apparel_BulletproofVest                                              None
# VAE_Apparel_GhillieSuit                                                  None
# VAE_Apparel_WoodenArmor                                                  None
# VAE_Headgear_StoneWarMask                                                0.05
# VAE_Headgear_TrooperHelmet                                               None
# VAE_Apparel_TrooperArmor                                                 None
# VAE_Headgear_HeavyMarineHelmet                                           None
# VAE_Apparel_HeavyMarineArmor                                             None
# VFEV_CryptoArmor                                                         None
# VFEV_Apparel_CryptoHeavyHelmet                                           None
# VAE_Apparel_BuildersJacket                                               None
# VAE_Apparel_DoctorScrubs                                                 None
# VAE_Apparel_LabCoat                                                      None
#
#                                                                                  offsets  \
# name
# VAE_Apparel_AdvancedVest                                                             NaN
# VAE_Apparel_PlateShoulderpads                                                        NaN
# VFEV_Apparel_GuardianArmor              {'MoveSpeed': '-1.1', 'MeleeDodgeChance': '-18'}
# VAE_Apparel_LightPlateArmor                                       {'MoveSpeed': '-0.12'}
# Apparel_PlateArmor                                                 {'MoveSpeed': '-0.8'}
# VAE_Apparel_Chestplate                                             {'MoveSpeed': '-0.2'}
# VFEV_Apparel_RavagerArmor                                 {'PainShockThreshold': '0.10'}
# VFEV_LeatherArmor                                                                    NaN
# VAE_Apparel_Chainmail                                              {'MoveSpeed': '-0.1'}
# VAE_Apparel_PlateHelmet                                 {'ShootingAccuracyPawn': '-0.1'}
# VAE_Apparel_MilitaryUniform            {'PainShockThreshold': '0.10', 'HuntingStealth...
# VAE_Apparel_QuiltedVest                                                              NaN
# VAE_Apparel_Jumpsuit                                         {'WorkSpeedGlobal': '0.10'}
# VAE_Apparel_Jeans                                                                    NaN
# VAE_Apparel_MilitaryJacket                             {'MentalBreakThreshold': '-0.10'}
# Apparel_Jacket                                                                       NaN
# Apparel_Duster                         {'SlaveSuppressionOffset': {'@MayRequire': 'Lu...
# VAE_Apparel_PeltCoat                                                                 NaN
# VAE_Apparel_Gambeson                                                                 NaN
# VFEV_Apparel_JarlCape                                                                NaN
# VFEV_Apparel_RoyalFurCoat                                                            NaN
# VAE_Apparel_ChefsUniform               {'CookSpeed': '0.15', 'Cleanliness': '0.10', '...
# VAE_Apparel_Apron                      {'WorkSpeedGlobal': '0.10', 'GeneralLaborSpeed...
# VAE_Apparel_SuitJacket                 {'SocialImpact': '0.10', 'TradePriceImprovemen...
# VAE_Apparel_Tunic                                                                    NaN
# VAE_Apparel_TankTop                    {'MeleeDodgeChance': '0.10', 'MoveSpeed': '0.05'}
# VAE_Apparel_TribalKilt                                                               NaN
# VAE_Apparel_TribalPoncho                                                             NaN
# VAE_Apparel_SheriffShirt                                  {'NegotiationAbility': '0.15'}
# VAE_Headgear_SummerHat                                                               NaN
# VAE_Headgear_TrapperHat                                                              NaN
# VAE_Apparel_Cape                                          {'PainShockThreshold': '0.10'}
# VAE_Apparel_Overalls                   {'PlantWorkSpeed': '0.10', 'PlantHarvestYield'...
# Apparel_TribalA                                                                      NaN
# VAE_Apparel_CasualTShirt                                                             NaN
# VAE_Headgear_Fedora                                             {'SocialImpact': '0.10'}
# Apparel_Parka                                                                        NaN
# Apparel_Pants                                                                        NaN
# Apparel_BasicShirt                                                                   NaN
# Apparel_CollarShirt                                                                  NaN
# Apparel_Burka                                                      {'MoveSpeed': '-0.4'}
# Apparel_Robe                                                                         NaN
# VAE_Headgear_Hood                                                                    NaN
# VAE_Apparel_Hoodie                                                                   NaN
# VAE_Apparel_ShirtandTie                {'SocialImpact': '0.10', 'TradePriceImprovemen...
# VAE_Apparel_Trousers                                            {'SocialImpact': '0.10'}
# VAE_Apparel_FleeceShirt                {'PlantWorkSpeed': '0.10', 'PlantHarvestYield'...
# Apparel_TortureCrown                                                                 NaN
# VAE_Apparel_Skirt                                               {'SocialImpact': '0.12'}
# VAE_Apparel_Blouse                                                                   NaN
# VAE_Apparel_Shorts                                                 {'MoveSpeed': '0.12'}
# Apparel_BodyStrap                                     {'SlaveSuppressionOffset': '0.15'}
# Apparel_Blindfold                                                                    NaN
# VAE_Apparel_HAZMATSuit                 {'PsychicSensitivity': '-0.75', 'ToxicSensitiv...
# Apparel_FlakVest                                                  {'MoveSpeed': '-0.12'}
# Apparel_FlakPants                                                 {'MoveSpeed': '-0.12'}
# Apparel_FlakJacket                                                {'MoveSpeed': '-0.12'}
# Apparel_ArmorReconPrestige             {'PsychicSensitivity': '0.05', 'PsychicEntropy...
# Apparel_ArmorHelmetReconPrestige       {'PsychicSensitivity': '0.05', 'PsychicEntropy...
# Apparel_ArmorMarinePrestige            {'PsychicSensitivity': '0.05', 'PsychicEntropy...
# Apparel_ArmorMarineHelmetPrestige      {'PsychicSensitivity': '0.05', 'PsychicEntropy...
# Apparel_ArmorCataphractPrestige        {'PsychicSensitivity': '0.05', 'PsychicEntropy...
# Apparel_ArmorHelmetCataphractPrestige  {'PsychicSensitivity': '0.05', 'PsychicEntropy...
# Apparel_ArmorLocust                                                                  NaN
# Apparel_ArmorMarineGrenadier                                                         NaN
# Apparel_ArmorCataphractPhoenix                                 {'Flammability': '-0.68'}
# Apparel_Gunlink                                            {'ShootingAccuracyPawn': '3'}
# VAE_Apparel_BulletproofVest                                                          NaN
# VAE_Apparel_GhillieSuit                {'HuntingStealth': '0.80', 'AimingDelayFactor'...
# VAE_Apparel_WoodenArmor                                                              NaN
# VAE_Headgear_StoneWarMask              {'PainShockThreshold': '0.10', 'MoveSpeed': '-...
# VAE_Headgear_TrooperHelmet                             {'MentalBreakThreshold': '-0.05'}
# VAE_Apparel_TrooperArmor               {'MentalBreakThreshold': '-0.05', 'MoveSpeed':...
# VAE_Headgear_HeavyMarineHelmet                            {'PainShockThreshold': '0.05'}
# VAE_Apparel_HeavyMarineArmor           {'PainShockThreshold': '0.05', 'MoveSpeed': '-...
# VFEV_CryptoArmor                                                                     NaN
# VFEV_Apparel_CryptoHeavyHelmet                                                       NaN
# VAE_Apparel_BuildersJacket             {'ConstructionSpeed': '0.10', 'ConstructSucces...
# VAE_Apparel_DoctorScrubs               {'MedicalSurgerySuccessChance': '0.15', 'Medic...
# VAE_Apparel_LabCoat                    {'ResearchSpeed': '0.10', 'DrugCookingSpeed': ...
#
#                                        move_speed
# name
# VAE_Apparel_AdvancedVest                      NaN
# VAE_Apparel_PlateShoulderpads                 NaN
# VFEV_Apparel_GuardianArmor                  -1.10
# VAE_Apparel_LightPlateArmor                 -0.12
# Apparel_PlateArmor                          -0.80
# VAE_Apparel_Chestplate                      -0.20
# VFEV_Apparel_RavagerArmor                    0.00
# VFEV_LeatherArmor                             NaN
# VAE_Apparel_Chainmail                       -0.10
# VAE_Apparel_PlateHelmet                      0.00
# VAE_Apparel_MilitaryUniform                  0.00
# VAE_Apparel_QuiltedVest                       NaN
# VAE_Apparel_Jumpsuit                         0.00
# VAE_Apparel_Jeans                             NaN
# VAE_Apparel_MilitaryJacket                   0.00
# Apparel_Jacket                                NaN
# Apparel_Duster                               0.00
# VAE_Apparel_PeltCoat                          NaN
# VAE_Apparel_Gambeson                          NaN
# VFEV_Apparel_JarlCape                         NaN
# VFEV_Apparel_RoyalFurCoat                     NaN
# VAE_Apparel_ChefsUniform                     0.00
# VAE_Apparel_Apron                            0.00
# VAE_Apparel_SuitJacket                       0.00
# VAE_Apparel_Tunic                             NaN
# VAE_Apparel_TankTop                          0.05
# VAE_Apparel_TribalKilt                        NaN
# VAE_Apparel_TribalPoncho                      NaN
# VAE_Apparel_SheriffShirt                     0.00
# VAE_Headgear_SummerHat                        NaN
# VAE_Headgear_TrapperHat                       NaN
# VAE_Apparel_Cape                             0.00
# VAE_Apparel_Overalls                         0.00
# Apparel_TribalA                               NaN
# VAE_Apparel_CasualTShirt                      NaN
# VAE_Headgear_Fedora                          0.00
# Apparel_Parka                                 NaN
# Apparel_Pants                                 NaN
# Apparel_BasicShirt                            NaN
# Apparel_CollarShirt                           NaN
# Apparel_Burka                               -0.40
# Apparel_Robe                                  NaN
# VAE_Headgear_Hood                             NaN
# VAE_Apparel_Hoodie                            NaN
# VAE_Apparel_ShirtandTie                      0.00
# VAE_Apparel_Trousers                         0.00
# VAE_Apparel_FleeceShirt                      0.00
# Apparel_TortureCrown                          NaN
# VAE_Apparel_Skirt                            0.00
# VAE_Apparel_Blouse                            NaN
# VAE_Apparel_Shorts                           0.12
# Apparel_BodyStrap                            0.00
# Apparel_Blindfold                             NaN
# VAE_Apparel_HAZMATSuit                      -0.50
# Apparel_FlakVest                            -0.12
# Apparel_FlakPants                           -0.12
# Apparel_FlakJacket                          -0.12
# Apparel_ArmorReconPrestige                   0.00
# Apparel_ArmorHelmetReconPrestige             0.00
# Apparel_ArmorMarinePrestige                  0.00
# Apparel_ArmorMarineHelmetPrestige            0.00
# Apparel_ArmorCataphractPrestige              0.00
# Apparel_ArmorHelmetCataphractPrestige        0.00
# Apparel_ArmorLocust                           NaN
# Apparel_ArmorMarineGrenadier                  NaN
# Apparel_ArmorCataphractPhoenix               0.00
# Apparel_Gunlink                              0.00
# VAE_Apparel_BulletproofVest                   NaN
# VAE_Apparel_GhillieSuit                      0.00
# VAE_Apparel_WoodenArmor                       NaN
# VAE_Headgear_StoneWarMask                   -0.10
# VAE_Headgear_TrooperHelmet                   0.00
# VAE_Apparel_TrooperArmor                     0.50
# VAE_Headgear_HeavyMarineHelmet               0.00
# VAE_Apparel_HeavyMarineArmor                -1.10
# VFEV_CryptoArmor                              NaN
# VFEV_Apparel_CryptoHeavyHelmet                NaN
# VAE_Apparel_BuildersJacket                   0.00
# VAE_Apparel_DoctorScrubs                     0.00
# VAE_Apparel_LabCoat                          0.00

# %%
QUALITY = {
    "awful": 0.6,
    "poor": 0.8,
    "normal": 1.0,
    "good": 1.15,
    "excellent": 1.3,
    "masterwork": 1.45,
    "legendary": 1.8
}

STUFF = {
    "metallic": {
        "gold": {"sharp": 0.72, "blunt": 0.36, "heat": 0.36},
        "plasteel": {"sharp": 1.14, "blunt": 0.55, "heat": 0.65},
        "steel": {"sharp": 0.9, "blunt": 0.45, "heat": 0.6},
        "uranium": {"sharp": 1.08, "blunt": 0.54, "heat": 0.65},
        "sky steel": {"sharp": 1.0, "blunt": 0.55, "heat": 0.35},
        "chtin": {"sharp": 0.92, "blunt": 0.18, "heat": 0.27}
    },
    "leather": {
        "thrumbofur": {"sharp": 2.08, "blunt": 0.36, "heat": 1.5},
        "hyperweave": {"sharp": 2, "blunt": 0.54, "heat": 2.88},
        "devilstrand": {"sharp": 1.4, "blunt": 0.36, "heat": 3},
        "heavy fur": {"sharp": 1.24, "blunt": 0.24, "heat": 1.5},
        "bearskin": {"sharp": 1.12, "blunt": 0.24, "heat": 1.5},
        "bluefur": {"sharp": 0.81, "blunt": 0.24, "heat": 1.5}
    }
}
        

def expand(src_rating=0, stuff=None):
    """stuff = metallic | leather | None"""
    data = []
    for quali, quali_factor in QUALITY.items():
        if stuff:
            for material, factors in STUFF[stuff].items():
                data.append({
                    "name": f"{quali}_{material}",
                    "sharp": src_rating * quali_factor * factors["sharp"],
                    "blunt": src_rating * quali_factor * factors["blunt"],
                    "heat": src_rating * quali_factor * factors["heat"]
                })
        else:
            data.append({
                "name": f"{quali}",
                "sharp": src_rating * quali_factor,
                "blunt": src_rating * quali_factor,
                "heat": src_rating * quali_factor
            })
    return pd.DataFrame.from_dict(data)

# %%
# leather armor
expand(src_rating=0.45, stuff="leather").sort_values(by="sharp", ascending=False).head(20)
# Out:
#                       name   sharp    blunt     heat
# 36    legendary_thrumbofur  1.6848  0.29160  1.21500
# 37    legendary_hyperweave  1.6200  0.43740  2.33280
# 30   masterwork_thrumbofur  1.3572  0.23490  0.97875
# 31   masterwork_hyperweave  1.3050  0.35235  1.87920
# 24    excellent_thrumbofur  1.2168  0.21060  0.87750
# 25    excellent_hyperweave  1.1700  0.31590  1.68480
# 38   legendary_devilstrand  1.1340  0.29160  2.43000
# 18         good_thrumbofur  1.0764  0.18630  0.77625
# 19         good_hyperweave  1.0350  0.27945  1.49040
# 39     legendary_heavy fur  1.0044  0.19440  1.21500
# 12       normal_thrumbofur  0.9360  0.16200  0.67500
# 32  masterwork_devilstrand  0.9135  0.23490  1.95750
# 40      legendary_bearskin  0.9072  0.19440  1.21500
# 13       normal_hyperweave  0.9000  0.24300  1.29600
# 26   excellent_devilstrand  0.8190  0.21060  1.75500
# 33    masterwork_heavy fur  0.8091  0.15660  0.97875
# 6          poor_thrumbofur  0.7488  0.12960  0.54000
# 34     masterwork_bearskin  0.7308  0.15660  0.97875
# 27     excellent_heavy fur  0.7254  0.14040  0.87750
# 20        good_devilstrand  0.7245  0.18630  1.55250

# %%
# leather armor
expand(src_rating=0.45, stuff="leather").sort_values(by="sharp", ascending=False).head(20)
# Out:
#                       name   sharp    blunt     heat
# 36    legendary_thrumbofur  1.6848  0.29160  1.21500
# 37    legendary_hyperweave  1.6200  0.43740  2.33280
# 30   masterwork_thrumbofur  1.3572  0.23490  0.97875
# 31   masterwork_hyperweave  1.3050  0.35235  1.87920
# 24    excellent_thrumbofur  1.2168  0.21060  0.87750
# 25    excellent_hyperweave  1.1700  0.31590  1.68480
# 38   legendary_devilstrand  1.1340  0.29160  2.43000
# 18         good_thrumbofur  1.0764  0.18630  0.77625
# 19         good_hyperweave  1.0350  0.27945  1.49040
# 39     legendary_heavy fur  1.0044  0.19440  1.21500
# 12       normal_thrumbofur  0.9360  0.16200  0.67500
# 32  masterwork_devilstrand  0.9135  0.23490  1.95750
# 40      legendary_bearskin  0.9072  0.19440  1.21500
# 13       normal_hyperweave  0.9000  0.24300  1.29600
# 26   excellent_devilstrand  0.8190  0.21060  1.75500
# 33    masterwork_heavy fur  0.8091  0.15660  0.97875
# 6          poor_thrumbofur  0.7488  0.12960  0.54000
# 34     masterwork_bearskin  0.7308  0.15660  0.97875
# 27     excellent_heavy fur  0.7254  0.14040  0.87750
# 20        good_devilstrand  0.7245  0.18630  1.55250

# %%
# advanced vest
expand(src_rating=1., stuff="metallic").sort_values(by="sharp", ascending=False).head(20)
# Out:
#                     name  sharp   blunt    heat
# 37    legendary_plasteel  2.052  0.9900  1.1700
# 39     legendary_uranium  1.944  0.9720  1.1700
# 40   legendary_sky steel  1.800  0.9900  0.6300
# 41       legendary_chtin  1.656  0.3240  0.4860
# 31   masterwork_plasteel  1.653  0.7975  0.9425
# 38       legendary_steel  1.620  0.8100  1.0800
# 33    masterwork_uranium  1.566  0.7830  0.9425
# 25    excellent_plasteel  1.482  0.7150  0.8450
# 34  masterwork_sky steel  1.450  0.7975  0.5075
# 27     excellent_uranium  1.404  0.7020  0.8450
# 35      masterwork_chtin  1.334  0.2610  0.3915
# 19         good_plasteel  1.311  0.6325  0.7475
# 32      masterwork_steel  1.305  0.6525  0.8700
# 28   excellent_sky steel  1.300  0.7150  0.4550
# 36        legendary_gold  1.296  0.6480  0.6480
# 21          good_uranium  1.242  0.6210  0.7475
# 29       excellent_chtin  1.196  0.2340  0.3510
# 26       excellent_steel  1.170  0.5850  0.7800
# 22        good_sky steel  1.150  0.6325  0.4025
# 13       normal_plasteel  1.140  0.5500  0.6500

# %%
# flak vest
expand(src_rating=0.55, stuff=None).sort_values(by="sharp", ascending=False).head(20)
# Out:
#          name   sharp   blunt    heat
# 6   legendary  0.9900  0.9900  0.9900
# 5  masterwork  0.7975  0.7975  0.7975
# 4   excellent  0.7150  0.7150  0.7150
# 3        good  0.6325  0.6325  0.6325
# 2      normal  0.5500  0.5500  0.5500
# 1        poor  0.4400  0.4400  0.4400
# 0       awful  0.3300  0.3300  0.3300

# %%
# marine armor
expand(src_rating=1.06, stuff=None).sort_values(by="sharp", ascending=False).head(20)
# Out:
#          name  sharp  blunt   heat
# 6   legendary  1.908  1.908  1.908
# 5  masterwork  1.537  1.537  1.537
# 4   excellent  1.378  1.378  1.378
# 3        good  1.219  1.219  1.219
# 2      normal  1.060  1.060  1.060
# 1        poor  0.848  0.848  0.848
# 0       awful  0.636  0.636  0.636

# %%
# heavy marine armor
expand(src_rating=1.18, stuff=None).sort_values(by="sharp", ascending=False).head(20)
# Out:
#          name  sharp  blunt   heat
# 6   legendary  2.124  2.124  2.124
# 5  masterwork  1.711  1.711  1.711
# 4   excellent  1.534  1.534  1.534
# 3        good  1.357  1.357  1.357
# 2      normal  1.180  1.180  1.180
# 1        poor  0.944  0.944  0.944
# 0       awful  0.708  0.708  0.708

# %%
# plate armor
expand(src_rating=0.73, stuff="metallic").sort_values(by="sharp", ascending=False).head(20)
# Out:
#                     name    sharp     blunt      heat
# 37    legendary_plasteel  1.49796  0.722700  0.854100
# 39     legendary_uranium  1.41912  0.709560  0.854100
# 40   legendary_sky steel  1.31400  0.722700  0.459900
# 41       legendary_chtin  1.20888  0.236520  0.354780
# 31   masterwork_plasteel  1.20669  0.582175  0.688025
# 38       legendary_steel  1.18260  0.591300  0.788400
# 33    masterwork_uranium  1.14318  0.571590  0.688025
# 25    excellent_plasteel  1.08186  0.521950  0.616850
# 34  masterwork_sky steel  1.05850  0.582175  0.370475
# 27     excellent_uranium  1.02492  0.512460  0.616850
# 35      masterwork_chtin  0.97382  0.190530  0.285795
# 19         good_plasteel  0.95703  0.461725  0.545675
# 32      masterwork_steel  0.95265  0.476325  0.635100
# 28   excellent_sky steel  0.94900  0.521950  0.332150
# 36        legendary_gold  0.94608  0.473040  0.473040
# 21          good_uranium  0.90666  0.453330  0.545675
# 29       excellent_chtin  0.87308  0.170820  0.256230
# 26       excellent_steel  0.85410  0.427050  0.569400
# 22        good_sky steel  0.83950  0.461725  0.293825
# 13       normal_plasteel  0.83220  0.401500  0.474500

# %%
with_offsets = armors[~pd.isna(armors.offsets)]
df = with_offsets.copy()
unique_offset_values = []
for offset in with_offsets.offsets:
    for k in offset:
        if k not in unique_offset_values:
            unique_offset_values.append(k)

for offset in unique_offset_values:
    df[offset] = with_offsets.offsets.apply(lambda x: x.get(offset, pd.NA))
    
df.columns
# Out:
# Index(['name', 'stuff_effect_multiplier_armor', 'armor_rating_sharp',
#        'armor_rating_blunt', 'armor_rating_heat', 'insulation_cold',
#        'insulation_heat', 'stuff_effect_multiplier_insulation_cold',
#        'stuff_effect_multiplier_insulation_heat', 'offsets', 'move_speed',
#        'SlaveSuppressionOffset', 'MoveSpeed', 'PsychicSensitivity',
#        'PsychicEntropyRecoveryRate', 'Flammability', 'ShootingAccuracyPawn',
#        'HuntingStealth', 'AimingDelayFactor', 'ToxicSensitivity',
#        'PainShockThreshold', 'MentalBreakThreshold', 'MeleeDodgeChance',
#        'SocialImpact', 'TradePriceImprovement', 'PlantWorkSpeed',
#        'PlantHarvestYield', 'AnimalGatherSpeed', 'AnimalGatherYield',
#        'CarryingCapacity', 'CookSpeed', 'Cleanliness', 'ButcheryFleshSpeed',
#        'ButcheryFleshEfficiency', 'ConstructionSpeed',
#        'ConstructSuccessChance', 'FixBrokenDownBuildingSuccessChance',
#        'MedicalSurgerySuccessChance', 'MedicalOperationSpeed',
#        'MedicalTendQuality', 'MedicalTendSpeed', 'ResearchSpeed',
#        'DrugCookingSpeed', 'DrugSynthesisSpeed', 'NegotiationAbility',
#        'WorkSpeedGlobal', 'GeneralLaborSpeed'],
#       dtype='object')

# %%
df[["name", 'WorkSpeedGlobal', 'GeneralLaborSpeed']]
# Out:
#                                      name WorkSpeedGlobal GeneralLaborSpeed
# 5                          Apparel_Duster            <NA>              <NA>
# 7                      Apparel_PlateArmor            <NA>              <NA>
# 8                        Apparel_FlakVest            <NA>              <NA>
# 9                       Apparel_FlakPants            <NA>              <NA>
# 10                     Apparel_FlakJacket            <NA>              <NA>
# 0                       Apparel_BodyStrap            <NA>              <NA>
# 1                           Apparel_Burka            <NA>              <NA>
# 0              Apparel_ArmorReconPrestige            <NA>              <NA>
# 1        Apparel_ArmorHelmetReconPrestige            <NA>              <NA>
# 2             Apparel_ArmorMarinePrestige            <NA>              <NA>
# 3       Apparel_ArmorMarineHelmetPrestige            <NA>              <NA>
# 4         Apparel_ArmorCataphractPrestige            <NA>              <NA>
# 5   Apparel_ArmorHelmetCataphractPrestige            <NA>              <NA>
# 8          Apparel_ArmorCataphractPhoenix            <NA>              <NA>
# 9                         Apparel_Gunlink            <NA>              <NA>
# 1                 VAE_Apparel_GhillieSuit            <NA>              <NA>
# 3                  VAE_Apparel_HAZMATSuit            <NA>              <NA>
# 2             VAE_Apparel_LightPlateArmor            <NA>              <NA>
# 4                  VAE_Apparel_Chestplate            <NA>              <NA>
# 5                   VAE_Apparel_Chainmail            <NA>              <NA>
# 6                 VAE_Apparel_PlateHelmet            <NA>              <NA>
# 1               VAE_Headgear_StoneWarMask            <NA>              <NA>
# 0              VAE_Headgear_TrooperHelmet            <NA>              <NA>
# 1                VAE_Apparel_TrooperArmor            <NA>              <NA>
# 2          VAE_Headgear_HeavyMarineHelmet            <NA>              <NA>
# 3            VAE_Apparel_HeavyMarineArmor            <NA>              <NA>
# 0              VFEV_Apparel_GuardianArmor            <NA>              <NA>
# 2               VFEV_Apparel_RavagerArmor            <NA>              <NA>
# 2                      VAE_Apparel_Shorts            <NA>              <NA>
# 3                       VAE_Apparel_Skirt            <NA>              <NA>
# 4                 VAE_Apparel_ShirtandTie            <NA>              <NA>
# 5                  VAE_Apparel_SuitJacket            <NA>              <NA>
# 6                    VAE_Apparel_Trousers            <NA>              <NA>
# 7                     VAE_Headgear_Fedora            <NA>              <NA>
# 8                    VAE_Apparel_Overalls            <NA>              <NA>
# 9                 VAE_Apparel_FleeceShirt            <NA>              <NA>
# 11               VAE_Apparel_ChefsUniform            <NA>              <NA>
# 12             VAE_Apparel_MilitaryJacket            <NA>              <NA>
# 13            VAE_Apparel_MilitaryUniform            <NA>              <NA>
# 14             VAE_Apparel_BuildersJacket            <NA>              <NA>
# 15               VAE_Apparel_DoctorScrubs            <NA>              <NA>
# 16                    VAE_Apparel_LabCoat            <NA>              <NA>
# 17                    VAE_Apparel_TankTop            <NA>              <NA>
# 18               VAE_Apparel_SheriffShirt            <NA>              <NA>
# 19                   VAE_Apparel_Jumpsuit            0.10              <NA>
# 2                       VAE_Apparel_Apron            0.10              0.10
# 3                        VAE_Apparel_Cape            <NA>              <NA>
